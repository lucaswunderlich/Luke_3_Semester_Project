# %%
import pandas as pd

# %%
nfl_teams = pd.read_csv("nfl_teams.csv")

# %% [markdown]
# ### Teams data

# %%
nfl_teams = pd.read_csv("nfl_teams.csv")
nfl_teams
# Out:
#                    team_name team_name_short team_id team_id_pfr  \
# 0          Arizona Cardinals       Cardinals     ARI         CRD
# 1            Atlanta Falcons         Falcons     ATL         ATL
# 2            Baltimore Colts           Colts     IND         CLT
# 3           Baltimore Ravens          Ravens     BAL         RAV
# 4            Boston Patriots        Patriots      NE         NWE
# 5              Buffalo Bills           Bills     BUF         BUF
# 6          Carolina Panthers        Panthers     CAR         CAR
# 7              Chicago Bears           Bears     CHI         CHI
# 8         Cincinnati Bengals         Bengals     CIN         CIN
# 9           Cleveland Browns          Browns     CLE         CLE
# 10            Dallas Cowboys         Cowboys     DAL         DAL
# 11            Denver Broncos         Broncos     DEN         DEN
# 12             Detroit Lions           Lions     DET         DET
# ...

# %% [markdown]
# ### Stadiums Data

# %%
nfl_stadiums = pd.read_csv("nfl_stadiums.csv")
nfl_stadiums
# Out:
#              stadium_name  stadium_location  stadium_open  stadium_close  \
# 0        Acrisure Stadium    Pittsburgh, PA        2001.0            NaN
# 1              Alamo Dome   San Antonio, TX           NaN            NaN
# 2       Allegiant Stadium      Paradise, NV        2020.0            NaN
# 3           Allianz Arena   Munich, Germany           NaN            NaN
# 4          Alltel Stadium  Jacksonville, FL           NaN            NaN
# ..                    ...               ...           ...            ...
# 113  War Memorial Stadium       Buffalo, NY        1960.0         1972.0
# 114       Wembley Stadium        London, UK        2007.0            NaN
# 115         Wrigley Field       Chicago, IL        1920.0         1970.0
# 116             Yale Bowl     New Haven, CT           NaN            NaN
# 117        Yankee Stadium         Bronx, NY           NaN            NaN
#
#     stadium_type                              stadium_address  \
# ...

# %% [markdown]
# ### Scores data

# %%
scores_df = pd.read_csv("spreadspoke_scores.csv")
scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division              True
# 13512     1/22/2023             2022      Division              True
# 13513     1/29/2023             2022    Conference              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %% [markdown]
# ### Add team id to scores

# %%
team_names = nfl_teams["team_name"]
# team_names
team_ids = nfl_teams["team_id"]
team_ids.drop_duplicates(inplace = True)
team_ids
# Out:
# 0     ARI
# 1     ATL
# 2     IND
# 3     BAL
# 4      NE
# 5     BUF
# 6     CAR
# 7     CHI
# 8     CIN
# 9     CLE
# 10    DAL
# 11    DEN
# 12    DET
# 13     GB
# 14    TEN
# 15    HOU
# 17    JAX
# 18     KC
# 19    LVR
# 20    LAC
# 22    LAR
# 23    MIA
# 24    MIN
# 26     NO
# 27    NYG
# 28    NYJ
# 30    PHI
# 32    PIT
# 34     SF
# 35    SEA
# 38     TB
# 41    WAS
# Name: team_id, dtype: object

# %%
home_team_ids_full_col = []
for team_name in scores_df.iloc[:,4]:
    for index in range(len(team_ids)):
        if team_name == team_names[index]:
            home_team_ids_full_col.append(team_ids[index])
            

scores_df["team_home_id"] = home_team_ids_full_col
# scores_df

# %%
away_team_ids_full_col = []
for team_name in scores_df.iloc[:,7]:
    for index in range(len(team_ids)):
        if team_name == team_names[index]:
            away_team_ids_full_col.append(team_ids[index])
            

scores_df["team_away_id"] = away_team_ids_full_col
# scores_df.drop("home_team_ids", 1, inplace=True)
# scores_df

# %%
#scores_df.dropna(0,subset = ["spread_favorite"], inplace=True)
scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division              True
# 13512     1/22/2023             2022      Division              True
# 13513     1/29/2023             2022    Conference              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %% [markdown]
# ### Adding stadium data

# %%
#nfl_stadiums

# %%
stadium_names = nfl_stadiums.iloc[:,0]
stadium_names
stadium_types = nfl_stadiums.iloc[:,7]
stadium_types
# Out:
# 0          cold
# 1          dome
# 2          dome
# 3      moderate
# 4           NaN
#          ...
# 113        cold
# 114    moderate
# 115        cold
# 116        cold
# 117        cold
# Name: stadium_weather_type, Length: 118, dtype: object

# %%
stadium_types_full_col = []
for stadium in scores_df.iloc[:,11]:
    added = False
    for index in range(len(stadium_names)):
        if stadium == stadium_names[index]:
            stadium_types_full_col.append(stadium_types[index])
            added = True
    if added == False:
        stadium_types_full_col.append("NaN")
            

scores_df["stadium_type"] = stadium_types_full_col
# scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division              True
# 13512     1/22/2023             2022      Division              True
# 13513     1/29/2023             2022    Conference              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %% [markdown]
# ### Data for divisional games

# %%
team_divisons = nfl_teams.iloc[:,2:6]
team_divisons_ids = nfl_teams[["team_id", "team_division"]]
team_divisons_ids.dropna(inplace = True)
team_divisons_ids = team_divisons_ids.iloc[:34]
team_divisons_ids.drop(29, inplace = True)
team_divisons_ids.drop(33, inplace = True)
team_divisons_ids
# Out:
# <ipython-input-185-2ccdf9d4a616>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_divisons_ids.dropna(inplace = True)
#    team_id team_division
# 0      ARI      NFC West
# 1      ATL     NFC South
# 3      BAL     AFC North
# 5      BUF      AFC East
# 6      CAR     NFC South
# 7      CHI     NFC North
# 8      CIN     AFC North
# 9      CLE     AFC North
# 10     DAL      NFC East
# 11     DEN      AFC West
# 12     DET     NFC North
# 13      GB     NFC North
# 15     HOU     AFC South
# 16     IND     AFC South
# 17     JAX     AFC South
# 18      KC      AFC West
# 20     LAC      AFC West
# 21     LVR      AFC West
# 22     LAR      NFC West
# 23     MIA      AFC East
# 24     MIN     NFC North
# 25      NE      AFC East
# 26      NO     NFC South
# 27     NYG      NFC East
# ...

# %%
team_divisons_ids = team_divisons_ids.reset_index()
team_ids2 = team_divisons_ids["team_id"]
team_divisions2 = team_divisons_ids["team_division"]
#team_ids2 = team_ids2.reset_index()
team_ids2
# Out:
# 0     ARI
# 1     ATL
# 2     BAL
# 3     BUF
# 4     CAR
# 5     CHI
# 6     CIN
# 7     CLE
# 8     DAL
# 9     DEN
# 10    DET
# 11     GB
# 12    HOU
# 13    IND
# 14    JAX
# 15     KC
# 16    LAC
# 17    LVR
# 18    LAR
# 19    MIA
# 20    MIN
# 21     NE
# 22     NO
# 23    NYG
# 24    NYJ
# 25    PHI
# 26    PIT
# 27     SF
# 28    SEA
# 29     TB
# 30    TEN
# 31    WAS
# Name: team_id, dtype: object

# %%
home_team_division_full_col = []
for team_home_id in scores_df.iloc[:,17]:
    for index in range(len(team_ids2)):
        if team_home_id == team_ids2[index]:
            home_team_division_full_col.append(team_divisions2[index])
            #print(team_home_id, team_divisions2[index])
            
scores_df["team_home_division"] = home_team_division_full_col
scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division              True
# 13512     1/22/2023             2022      Division              True
# 13513     1/29/2023             2022    Conference              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %%
away_team_division_full_col = []
for team_away_id in scores_df.iloc[:,18]:
    for index in range(len(team_ids2)):
        if team_away_id == team_ids2[index]:
            away_team_division_full_col.append(team_divisions2[index])
            #print(team_home_id, team_divisions2[index])
            
scores_df["team_away_division"] = away_team_division_full_col
scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division              True
# 13512     1/22/2023             2022      Division              True
# 13513     1/29/2023             2022    Conference              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %%
divisional_game = []
for index in range(len(away_team_division_full_col)):
    if home_team_division_full_col[index] == away_team_division_full_col[index]:
        divisional_game.append(1)
    else:
        divisional_game.append(0)
        
scores_df["divisional_game"] = divisional_game
scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division              True
# 13512     1/22/2023             2022      Division              True
# 13513     1/29/2023             2022    Conference              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %% [markdown]
# ### What team was favorite

# %%
home_favorite = []
favorited_teams = scores_df.iloc[:,8]
for index in range(len(favorited_teams)):
    if favorited_teams[index] == home_team_ids_full_col[index]:
        home_favorite.append(1)
    else:
        home_favorite.append(0)
        
scores_df["home_favorite"] = home_favorite
scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division              True
# 13512     1/22/2023             2022      Division              True
# 13513     1/29/2023             2022    Conference              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %% [markdown]
# ### Game type
# 1-18 week
# -1 = wildcard
# -2 = divisional
# -3 = conference
# -4 = superbowl

# %%
week_type = []
for week in scores_df.iloc[:,2]:
    if week == "Wildcard":
        week_type.append(-1)
    elif week == "Division":
        week_type.append(-2)
    elif week == "Conference":
        week_type.append(-3)
    elif week == "Superbowl":
        week_type.append(-4)
    else:
        week_type.append(int(week))
scores_df["week_type"] = week_type
scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division              True
# 13512     1/22/2023             2022      Division              True
# 13513     1/29/2023             2022    Conference              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %%
spread = spread_favorite
#if spread_favorite
if home_favorite == 1:
    if score_home - spread > acore_away:
        hit
    else:
        not hit
else:
    if score_away - spread > score_home:
        hit
    else:
        not hit

# %%
spreads = scores_df.iloc[:,9]
home_scores = scores_df.iloc[:,5]
away_scores = scores_df.iloc[:,6]

# %%
spread_hit = []
for index in range(len(home_favorite)):
    spread = spreads[index]
    home_score = home_scores[index]
    away_score = away_scores[index]
    if home_favorite[index] == 1:
        if home_score + spread > away_score:
            spread_hit.append(1)
        else:
            spread_hit.append(0)
            
    else:
        if away_score + spread > home_score:
            spread_hit.append(1)
        else:
            spread_hit.append(0)

# %%
scores_df["spread_hit"] = spread_hit
scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division              True
# 13512     1/22/2023             2022      Division              True
# 13513     1/29/2023             2022    Conference              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %% [markdown]
# Stadium Type
# 0 = dome
# 1 = warm
# 2 = moderate
# 3 = cold

# %%
#scores_df[["stadium_type"]]

stadium_types = []
for st_type in scores_df.iloc[:,19]:
    if st_type == "dome":
        stadium_types.append(0)
    elif st_type == "warm":
        stadium_types.append(1)
    elif st_type == "moderate":
        stadium_types.append(2)
    elif st_type == "cold":
        stadium_types.append(3)
    else:
        stadium_types.append(-1)

scores_df["stadium_types"] = stadium_types
scores_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1                 0
# 1          9/3/1966             1966             1                 0
# 2          9/4/1966             1966             1                 0
# 3          9/9/1966             1966             2                 0
# 4         9/10/1966             1966             1                 0
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division                 1
# 13512     1/22/2023             2022      Division                 1
# 13513     1/29/2023             2022    Conference                 1
# 13514     1/29/2023             2022    Conference                 1
# 13515     2/12/2023             2022     Superbowl                 1
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %%
schedule_playoff = scores_df.iloc[:,3].astype(int)
scores_df["schedule_playoff"] = schedule_playoff
scores_df

# Create columns for each weatherhttps://github.com/users/lucaswunderlich/projects/1
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1                 0
# 1          9/3/1966             1966             1                 0
# 2          9/4/1966             1966             1                 0
# 3          9/9/1966             1966             2                 0
# 4         9/10/1966             1966             1                 0
# ...             ...              ...           ...               ...
# 13511     1/22/2023             2022      Division                 1
# 13512     1/22/2023             2022      Division                 1
# 13513     1/29/2023             2022    Conference                 1
# 13514     1/29/2023             2022    Conference                 1
# 13515     2/12/2023             2022     Superbowl                 1
#
#                  team_home  score_home  score_away            team_away  \
# ...

# %%
df = scores_df[["week_type", "schedule_playoff", "stadium_types","home_favorite", "spread_hit"]]
df = df.dropna()
# , "divisional_game"

df.dtypes
# Out:
# week_type           int64
# schedule_playoff    int64
# stadium_types       int64
# home_favorite       int64
# spread_hit          int64
# dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn import metrics

# %%
train_vectors, test_vectors, train_labels, test_labels = train_test_split(df.loc[:,df.columns != "spread_hit"], df.loc[:,"spread_hit"])

# %%
logit_model = sm.Logit(train_labels, sm.add_constant(train_vectors))
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.644930
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:             spread_hit   No. Observations:                10137
# Model:                          Logit   Df Residuals:                    10132
# Method:                           MLE   Df Model:                            4
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                 0.03285
# Time:                        09:11:10   Log-Likelihood:                -6537.7
# converged:                       True   LL-Null:                       -6759.7
# Covariance Type:            nonrobust   LLR p-value:                 7.869e-95
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -1.0169      0.061    -16.664      0.000      -1.137      -0.897
# ...

# %%
predicted = result.predict(sm.add_constant(test_vectors))

predicted = predicted.mask(predicted < 0.5, 0)
predicted = predicted.mask(predicted >= 0.5, 1)
predicted
# Out:
# 8215     0.0
# 12714    0.0
# 10169    0.0
# 11951    0.0
# 10417    0.0
#         ...
# 6581     1.0
# 13031    0.0
# 9684     1.0
# 2264     0.0
# 2737     0.0
# Length: 3379, dtype: float64

# %%
metrics.accuracy_score(test_labels, predicted)
# Out:
# 0.6087599881621781
